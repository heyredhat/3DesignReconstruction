# %%
from vibes import *

# %%
P = construct_P(3, 3, 2)
# Out:
# /Users/heyredhat/opt/anaconda3/envs/spring2025/lib/python3.12/site-packages/scipy/optimize/_minimize.py:733: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 0.000000
#          Iterations: 100
#          Function evaluations: 147
#          Gradient evaluations: 143

# %%
check_P(P)
# Out:
# {'non-negative': True,
#  'stochastic': True,
#  'symmetric': True,
#  'unbiased': True,
#  'depolarizing': True}

# %%
extract_P_data(P)
# Out:
# {'n': 3,
#  'r': 3,
#  'alpha': 2.0000000000000004,
#  'beta': -0.3333333333333335,
#  'gamma': 1.5000000000000002,
#  'Phi': array([[ 1.667, -0.333, -0.333],
#         [-0.333,  1.667, -0.333],
#         [-0.333, -0.333,  1.667]])}

# %%
valid = valid_probabilities(10, P)
valid
# Out:
# (array([[0.103, 0.597, 0.3  ],
#         [0.185, 0.324, 0.491],
#         [0.458, 0.39 , 0.152],
#         [0.671, 0.132, 0.196],
#         [0.295, 0.535, 0.17 ],
#         [0.201, 0.122, 0.676],
#         [0.33 , 0.498, 0.172],
#         [0.463, 0.34 , 0.197],
#         [0.685, 0.131, 0.184],
#         [0.421, 0.2  , 0.38 ]]),
#  0.47619047619047616)

# %%
# %matplotlib widget 
P = construct_P(2, 2, 2)
viz_state_space(P)
# Out:
# /Users/heyredhat/opt/anaconda3/envs/spring2025/lib/python3.12/site-packages/scipy/optimize/_minimize.py:733: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 0.000000
#          Iterations: 53
#          Function evaluations: 112
#          Gradient evaluations: 110
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget 
P = construct_P(3, 3, 2)
viz_state_space(P, embed=False)
# Out:
# /Users/heyredhat/opt/anaconda3/envs/spring2025/lib/python3.12/site-packages/scipy/optimize/_minimize.py:733: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 0.000000
#          Iterations: 93
#          Function evaluations: 147
#          Gradient evaluations: 146
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget 
viz_state_space(P, embed=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget 
P = construct_P(4, 3, 2)
viz_state_space(P, embed=True)
# Out:
# /Users/heyredhat/opt/anaconda3/envs/spring2025/lib/python3.12/site-packages/scipy/optimize/_minimize.py:733: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 0.000000
#          Iterations: 123
#          Function evaluations: 174
#          Gradient evaluations: 174
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
